# %%
from Bio import Phylo
import matplotlib
import matplotlib.pyplot as plt

# %%
path2tree = "../inputs/panX/rso_test/strain_tree.nwk"
tree = Phylo.read(path2tree, "newick")
print(tree)
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade(branch_length=0.0001, name='NODE_0000000')
#         Clade(branch_length=0.68531, name='GCF_001587135.1_ASM158713v1_genomic')
#         Clade(branch_length=0.68531, name='NODE_0000001')
#             Clade(branch_length=0.56904, name='GCF_001586135.1_ASM158613v1_genomic')
#             Clade(branch_length=1.17118, name='NODE_0000002')
#                 Clade(branch_length=0.01858, name='NODE_0000003')
#                     Clade(branch_length=0.00711, name='GCF_013306435.1_ASM1330643v1_genomic')
#                     Clade(branch_length=0.01335, name='NODE_0000004')
#                         Clade(branch_length=0.0, name='GCF_013306335.1_ASM1330633v1_genomic')
#                         Clade(branch_length=0.0, name='GCF_013306935.1_ASM1330693v1_genomic')
#                 Clade(branch_length=0.00838, name='NODE_0000005')
#                     Clade(branch_length=0.01852, name='GCF_013306235.1_ASM1330623v1_genomic')
#                     Clade(branch_length=0.01347, name='NODE_0000006')
#                         Clade(branch_length=0.00722, name='GCF_001887535.1_ASM188753v1_genomic')
#                         Clade(branch_length=0.00704, name='GCF_013375735.1_ASM1337573v1_genomic')

# %%
fig = plt.figure(figsize=(15, 12), dpi=100)
axes = fig.add_subplot(1, 1, 1)

Phylo.draw(tree, axes=axes)

# %%
for c in tree.find_clades():
    print("Clade", c.name)
# Out:
# Clade NODE_0000000
# Clade GCF_001587135.1_ASM158713v1_genomic
# Clade NODE_0000001
# Clade GCF_001586135.1_ASM158613v1_genomic
# Clade NODE_0000002
# Clade NODE_0000003
# Clade GCF_013306435.1_ASM1330643v1_genomic
# Clade NODE_0000004
# Clade GCF_013306335.1_ASM1330633v1_genomic
# Clade GCF_013306935.1_ASM1330693v1_genomic
# Clade NODE_0000005
# Clade GCF_013306235.1_ASM1330623v1_genomic
# Clade NODE_0000006
# Clade GCF_001887535.1_ASM188753v1_genomic
# Clade GCF_013375735.1_ASM1337573v1_genomic

# %%
print(tree.split())
# Out:
# None
